# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('train.csv')
dataset.head(10)
# Out:
#    id  traffic_volume holiday        temp   rain_1h    snow_1h  clouds_all  \
# 0   0     5977.718652    None  334.271282  7.077448   2.175000          40
# 1   1     4868.417932    None  335.523582  5.055320   7.612501          75
# 2   2     5139.005377    None  335.778680  8.088512   3.262500          90
# 3   3     5418.217122    None  336.416425  6.066384   8.700001          90
# 4   4     5301.789059    None  337.587557  5.055320  13.050001          75
# 5   5     5585.312955    None  338.260089  2.022128  10.875001           1
# 6   6     6019.762119    None  339.941417  3.033192   8.700001           1
# 7   7     6484.396337    None  340.741497  4.044256   3.262500           1
# 8   8     6242.915908    None  341.066168  0.000000   2.175000          20
# 9   9     5142.239489    None  339.860249  6.066384   2.175000          20
#
#   weather_main weather_description         date_time
# 0       Clouds    scattered clouds  02-10-2012 09:00
# ...

# %%
dataset.drop(['id'],axis=1,inplace=True)
dataset.head(10)
# Out:
#    traffic_volume holiday        temp   rain_1h    snow_1h  clouds_all  \
# 0     5977.718652    None  334.271282  7.077448   2.175000          40
# 1     4868.417932    None  335.523582  5.055320   7.612501          75
# 2     5139.005377    None  335.778680  8.088512   3.262500          90
# 3     5418.217122    None  336.416425  6.066384   8.700001          90
# 4     5301.789059    None  337.587557  5.055320  13.050001          75
# 5     5585.312955    None  338.260089  2.022128  10.875001           1
# 6     6019.762119    None  339.941417  3.033192   8.700001           1
# 7     6484.396337    None  340.741497  4.044256   3.262500           1
# 8     6242.915908    None  341.066168  0.000000   2.175000          20
# 9     5142.239489    None  339.860249  6.066384   2.175000          20
#
#   weather_main weather_description         date_time
# 0       Clouds    scattered clouds  02-10-2012 09:00
# 1       Clouds       broken clouds  02-10-2012 10:00
# ...

# %%
len(dataset)
# Out:
# 28923

# %%
print(dataset['holiday'].value_counts())
print(len(dataset['holiday'].value_counts()))
# Out:
# None                         28886
# Thanksgiving Day                 5
# Columbus Day                     4
# Veterans Day                     4
# New Years Day                    4
# Labor Day                        4
# Christmas Day                    3
# Washingtons Birthday             3
# Memorial Day                     3
# Independence Day                 3
# State Fair                       3
# Martin Luther King Jr Day        1
# Name: holiday, dtype: int64
# 12

# %%
dataset.drop(['holiday'],axis=1,inplace=True)
dataset.head(10)
# Out:
#    traffic_volume        temp   rain_1h    snow_1h  clouds_all weather_main  \
# 0     5977.718652  334.271282  7.077448   2.175000          40       Clouds
# 1     4868.417932  335.523582  5.055320   7.612501          75       Clouds
# 2     5139.005377  335.778680  8.088512   3.262500          90       Clouds
# 3     5418.217122  336.416425  6.066384   8.700001          90       Clouds
# 4     5301.789059  337.587557  5.055320  13.050001          75       Clouds
# 5     5585.312955  338.260089  2.022128  10.875001           1        Clear
# 6     6019.762119  339.941417  3.033192   8.700001           1        Clear
# 7     6484.396337  340.741497  4.044256   3.262500           1        Clear
# 8     6242.915908  341.066168  0.000000   2.175000          20       Clouds
# 9     5142.239489  339.860249  6.066384   2.175000          20       Clouds
#
#   weather_description         date_time
# 0    scattered clouds  02-10-2012 09:00
# 1       broken clouds  02-10-2012 10:00
# ...

# %%
print("weather_main	->")
print(len(dataset['weather_main'].value_counts()))
print(dataset['weather_main'].value_counts().sum())
print(dataset['weather_main'].value_counts())
print(dataset['weather_main'].unique())
# Out:
# weather_main	->
# 11
# 28923
# Clouds          10047
# Clear            7832
# Rain             3536
# Mist             3360
# Snow             1559
# Drizzle           898
# Haze              698
# Thunderstorm      496
# Fog               476
# Smoke              17
# Squall              4
# Name: weather_main, dtype: int64
# ['Clouds' 'Clear' 'Rain' 'Drizzle' 'Mist' 'Haze' 'Fog' 'Thunderstorm'
#  'Snow' 'Squall' 'Smoke']

# %%
# plt.figure(figsize=(100, 10))
# sns.barplot(x='weather_description', y='traffic_volume', data=dataset)
# # plt.title('Values for Repeating Elements')
# plt.xlabel('weather_description')
# plt.ylabel('traffic_volume')
# plt.show()

# %%
# plt.figure(figsize=(100, 10))
# sns.boxplot(x='weather_description', y='traffic_volume', data=dataset)
# # plt.title('Values for Repeating Elements')
# plt.xlabel('weather_description')
# plt.ylabel('traffic_volume')
# plt.show()

# %%
# @title Default title text
# plt.figure(figsize=(40, 10))
# sns.boxplot(x='weather_main', y='traffic_volume', data=dataset)
# # plt.title('Values for Repeating Elements')
# plt.xlabel('weather_main')
# plt.ylabel('traffic_volume')
# plt.show()

# %%
# plt.figure(figsize=(50, 10))
# sns.barplot(x='weather_main', y='traffic_volume', data=dataset)
# # plt.title('Values for Repeating Elements')
# plt.xlabel('weather_main')
# plt.ylabel('traffic_volume')
# plt.show()

# %%
# print("weather_description	->")
# print(len(dataset['weather_description'].value_counts()))
# print(dataset['weather_description'].value_counts())
# print(dataset['weather_description'].unique())

# %%
# dataset['weather_description'].replace('thunderstorm', 'thunderstorm with light rain', inplace=True)

# %%
# print("weather_description->")
# print(len(dataset['weather_description'].value_counts()))
# print(dataset['weather_description'].value_counts())
# print(dataset['weather_description'].unique())

# %%
# dataset = dataset[dataset['weather_description'] != 'shower snow']
# dataset = dataset[dataset['weather_description'] != 'shower drizzle']
# dataset = dataset[dataset['weather_description'] != 'freezing rain']
# dataset = dataset[dataset['weather_description'] != 'thunderstorm with drizzle']
# dataset = dataset[dataset['weather_description'] != 'thunderstorm with light drizzle']
# dataset = dataset[dataset['weather_description'] != 'light rain and snow']

# print(dataset['weather_description'].value_counts())

# %%
category_mapping={
  'Clear':1,'Clouds':2,'Mist':3,'Haze':4,'Smoke':5,'Drizzle':6,'Rain':7,'Thunderstorm':8,'Snow':9,'Squall':10,'Fog':11
}
dataset['weather_main'] = dataset['weather_main'].replace(category_mapping)
dataset.head()

dataset.drop(['weather_description'],axis=1,inplace=True)
dataset.head(10)



# category_mapping={
#   'sky is clear':1,'Sky is Clear':1,'scattered clouds':2,'broken clouds':3,'overcast clouds':4,'few clouds':5,'Mist':6,'haze':7,'smoke':8,'fog':9,'drizzle':10,'light intensity drizzle':11,'light rain':13,'light intensity shower rain':14,'light snow':15,'thunderstorm with light rain':16,'proximity thunderstorm':17,'proximity thunderstorm with drizzle':18,'proximity thunderstorm with rain':19,'proximity shower rain':20,'moderate rain':21,'thunderstorm with rain':22,'heavy intensity rain':23,'very heavy rain':24,'thunderstorm':25,'thunderstorm with heavy rain':26,'snow':27,'heavy snow':28,'heavy intensity drizzle':29
# }
# dataset['weather_description'] = dataset['weather_description'].replace(category_mapping)
# dataset.head()

# dataset.drop(['weather_main'],axis=1,inplace=True)
# dataset.head(10)



# category_mapping={
#   'Clear':1,'Clouds':2,'Mist':3,'Haze':4,'Smoke':5,'Drizzle':6,'Rain':7,'Thunderstorm':8,'Snow':9,'Squall':10,'Fog':11
# }
# dataset['weather_description'] = dataset['weather_description'].replace(category_mapping)
# dataset.head()

# dataset.drop(['weather_main'],axis=1,inplace=True)
# dataset.head(10)
# Out:
#    traffic_volume        temp   rain_1h    snow_1h  clouds_all  weather_main  \
# 0     5977.718652  334.271282  7.077448   2.175000          40             2
# 1     4868.417932  335.523582  5.055320   7.612501          75             2
# 2     5139.005377  335.778680  8.088512   3.262500          90             2
# 3     5418.217122  336.416425  6.066384   8.700001          90             2
# 4     5301.789059  337.587557  5.055320  13.050001          75             2
# 5     5585.312955  338.260089  2.022128  10.875001           1             1
# 6     6019.762119  339.941417  3.033192   8.700001           1             1
# 7     6484.396337  340.741497  4.044256   3.262500           1             1
# 8     6242.915908  341.066168  0.000000   2.175000          20             2
# 9     5142.239489  339.860249  6.066384   2.175000          20             2
#
#           date_time
# 0  02-10-2012 09:00
# 1  02-10-2012 10:00
# 2  02-10-2012 11:00
# 3  02-10-2012 12:00
# ...

# %%
def create_date_features(data_frame):
	df = data_frame.copy()
	df['year'] = df.date_time.dt.year
	df['month'] = df.date_time.dt.month
	df['day'] = df.date_time.dt.day
	df['hour'] = df.date_time.dt.hour
	df['dayofweek'] = df.date_time.dt.day_of_week
	df.drop('date_time', axis=1, inplace=True)
	return df

# %%
dataset['date_time'] = pd.to_datetime(dataset['date_time'], format='%d-%m-%Y %H:%M')

dataset = create_date_features(dataset)
dataset.head(10)
# Out:
#    traffic_volume        temp   rain_1h    snow_1h  clouds_all  weather_main  \
# 0     5977.718652  334.271282  7.077448   2.175000          40             2
# 1     4868.417932  335.523582  5.055320   7.612501          75             2
# 2     5139.005377  335.778680  8.088512   3.262500          90             2
# 3     5418.217122  336.416425  6.066384   8.700001          90             2
# 4     5301.789059  337.587557  5.055320  13.050001          75             2
# 5     5585.312955  338.260089  2.022128  10.875001           1             1
# 6     6019.762119  339.941417  3.033192   8.700001           1             1
# 7     6484.396337  340.741497  4.044256   3.262500           1             1
# 8     6242.915908  341.066168  0.000000   2.175000          20             2
# 9     5142.239489  339.860249  6.066384   2.175000          20             2
#
#    year  month  day  hour  dayofweek
# 0  2012     10    2     9          1
# 1  2012     10    2    10          1
# ...

# %%
X = dataset.iloc[:,1:].values
y = dataset.iloc[:,0].values

# %%
X
# Out:
# array([[334.27128182,   7.07744837,   2.17500019, ...,   2.        ,
#           9.        ,   1.        ],
#        [335.52358161,   5.05532027,   7.61250066, ...,   2.        ,
#          10.        ,   1.        ],
#        [335.77867972,   8.08851243,   3.26250028, ...,   2.        ,
#          11.        ,   1.        ],
#        ...,
#        [307.9961769 ,   6.06638432,   4.35000038, ...,   8.        ,
#           6.        ,   3.        ],
#        [308.29765648,   3.03319216,   4.35000038, ...,   8.        ,
#           7.        ,   3.        ],
#        [308.29765648,   3.03319216,   8.70000075, ...,   8.        ,
#           7.        ,   3.        ]])

# %%
# pip install keras-tuner

# %%
# import tensorflow_decision_forests as tfdf
# from kerastuner.tuners import RandomSearch

# def build_tfbt_model(hp):
#     model = tfdf.keras.GradientBoostedTreesModel(
#         max_depth=hp.Int('max_depth', min_value=3, max_value=10, step=1),
#         l1_regularization=hp.Float('l1_regularization', min_value=0.0, max_value=1.0),
#         l2_regularization=hp.Float('l2_regularization', min_value=0.0, max_value=1.0)
#     )
#     model.compile(metrics=['r2'])
#     return model

# tuner = RandomSearch(
#     build_tfbt_model,
#     objective='val_r2',  # Use the validation mean squared error as the optimization metric
#     max_trials=10,  # Number of hyperparameter combinations to try
#     executions_per_trial=1,  # Number of training runs per trial
#     directory='my_dir',  # Directory to store results
#     project_name='my_tuning_project'  # Name of the tuning project
# )

# tuner.search(X_train, y_train, epochs=10, validation_data=(X_test, y_test))

# best_hp = tuner.get_best_hyperparameters()[0]

# best_tfbt_model = build_tfbt_model(best_hp)
# best_tfbt_model.fit(X, y)

# %%
pip install ngboost
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 350.7/350.7 kB 11.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 13.7 MB/s eta 0:00:00
# ...
#   Created wheel for autograd-gamma: filename=autograd_gamma-0.5.0-py3-none-any.whl size=4031 sha256=30bc07594bb3c7819053fdb354237d85c64d88525ee355ae31f312e1da81834f
#   Stored in directory: /root/.cache/pip/wheels/25/cc/e0/ef2969164144c899fedb22b338f6703e2b9cf46eeebf254991
# Successfully built autograd-gamma
# ...

# %%
from sklearn.model_selection import RandomizedSearchCV
from ngboost import NGBRegressor

# %%
param_dist = {
    'n_estimators': [300,500,750],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'max_depth': [10,20,30],
    'min_child_weight': [1, 2, 3],
    'colsample_bytree': [0.8, 0.9, 1.0],
    'min_samples_split': [2, 3, 5],
    'min_samples_leaf': [5, 6, 7],
    'num_leaves': [31, 50, 100],
    'subsample': [0.8, 0.9, 1.0],
    'colsample_bytree': [0.8, 0.9, 1.0],
    'reg_alpha': [0, 0.1, 0.5],
    'reg_lambda': [0, 0.1, 0.5]
}

ngboost_regressor = NGBRegressor()

# Perform hyperparameter tuning
Modelb = RandomizedSearchCV(
    estimator=ngboost_regressor,
    param_distributions=param_dist,
    n_iter=10,
    cv=5,
    scoring='r2',
    n_jobs=-1,
    verbose = 5,
    refit=True
)

# %%
# from sklearn.model_selection import RandomizedSearchCV
# import lightgbm as lgb

# %%
# param_grid = {
#     'n_estimators': [750],
#     'objective': ['regression'],
#     'boosting_type': ['gbdt', 'dart', 'goss'],
#     'max_depth': [15, 20, 25],
#     'min_samples_split': [2, 3, 5],
#     'min_samples_leaf': [5, 6, 7],
#     'learning_rate': [0.01, 0.05, 0.1],
#     'num_leaves': [31, 50, 100],
#     'min_child_weight': [1, 2, 3],
#     'subsample': [0.8, 0.9, 1.0],
#     'colsample_bytree': [0.8, 0.9, 1.0],
#     'reg_alpha': [0, 0.1, 0.5],
#     'reg_lambda': [0, 0.1, 0.5]
# }

# Modela = RandomizedSearchCV(
#     estimator=lgb.LGBMRegressor(random_state=42),
#     param_distributions=param_grid,
#     n_iter=10,
#     cv=5,
#     scoring='r2',
#     n_jobs=-1,
#     verbose = 5,
#     refit=True
# )

# %%
# !nvidia-smi

# %%
# import tensorflow as tf
# print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

# %%
# import tensorflow as tf

# # Check if a TPU is available and the current runtime type
# try:
#     tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection
#     tf.config.experimental_connect_to_cluster(tpu)
#     tf.tpu.experimental.initialize_tpu_system(tpu)
#     tpu_address = tpu.master()

#     print("Using TPU:", tpu_address)

# except ValueError:
#     print("No TPU available. Using CPU.")

# %%
# import tensorflow as tf

# # Check if a GPU is available
# if tf.test.gpu_device_name() == "":
#     print("No GPU available. Switching to CPU...")
# else:
#     print("GPU available. Enabling GPU...")

#     # Change the runtime to GPU
#     import os
#     os.environ['COLAB_GPU'] = '1'

# %%
# import tensorflow as tf

# # Check if a GPU is available and the current runtime type
# if tf.test.gpu_device_name() == "":
#     print("No GPU available. Using CPU.")
# else:
#     print("GPU available. Using GPU.")

# %%
# !nvidia-smi

# %%
X
# Out:
# array([[334.27128182,   7.07744837,   2.17500019, ...,   2.        ,
#           9.        ,   1.        ],
#        [335.52358161,   5.05532027,   7.61250066, ...,   2.        ,
#          10.        ,   1.        ],
#        [335.77867972,   8.08851243,   3.26250028, ...,   2.        ,
#          11.        ,   1.        ],
#        ...,
#        [307.9961769 ,   6.06638432,   4.35000038, ...,   8.        ,
#           6.        ,   3.        ],
#        [308.29765648,   3.03319216,   4.35000038, ...,   8.        ,
#           7.        ,   3.        ],
#        [308.29765648,   3.03319216,   8.70000075, ...,   8.        ,
#           7.        ,   3.        ]])

# %%
Modela.fit(X, y)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=7. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] Unknown parameter: min_samples_split
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=7. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] Unknown parameter: min_samples_split
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000941 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 648
# [LightGBM] [Info] Number of data points in the train set: 28923, number of used features: 10
# [LightGBM] [Info] Start training from score 3491.231887
# RandomizedSearchCV(cv=5, estimator=LGBMRegressor(random_state=42), n_jobs=-1,
# ...

# %%
best_params = Modela.best_params_
print(best_params)
print("\n \n \n")
best_catboost_regressor = Modela.best_estimator_
print(best_catboost_regressor)
# Out:
# {'subsample': 1.0, 'reg_lambda': 0, 'reg_alpha': 0.1, 'objective': 'regression', 'num_leaves': 50, 'n_estimators': 750, 'min_samples_split': 5, 'min_samples_leaf': 7, 'min_child_weight': 1, 'max_depth': 15, 'learning_rate': 0.1, 'colsample_bytree': 0.8, 'boosting_type': 'dart'}
#
#
#
#
# LGBMRegressor(boosting_type='dart', colsample_bytree=0.8, max_depth=15,
#               min_child_weight=1, min_samples_leaf=7, min_samples_split=5,
#               n_estimators=750, num_leaves=50, objective='regression',
#               random_state=42, reg_alpha=0.1, reg_lambda=0)

# %%
Modelb.fit(X, y)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [iter 0] loss=9.0919 val_loss=0.0000 scale=1.0000 norm=1890.1315
# [iter 100] loss=7.3612 val_loss=0.0000 scale=0.0000 norm=0.0013
# [iter 200] loss=7.3612 val_loss=0.0000 scale=0.0000 norm=0.0013
# [iter 300] loss=7.3612 val_loss=0.0000 scale=0.0000 norm=0.0013
# [iter 400] loss=7.3612 val_loss=0.0000 scale=0.0000 norm=0.0013
# RandomizedSearchCV(cv=5,
#                    estimator=NGBRegressor(random_state=RandomState(MT19937) at 0x788589387640),
#                    n_jobs=-1,
#                    param_distributions={'colsample_bytree': [0.8, 0.9, 1.0],
#                                         'learning_rate': [0.01, 0.05, 0.1, 0.2],
#                                         'max_depth': [10, 20, 30],
#                                         'min_child_weight': [1, 2, 3],
#                                         'min_samples_leaf': [5, 6, 7],
# ...

# %%
best_params = Modelb.best_params_
print(best_params)
print("\n \n")
best_ngboost_model = Modelb.best_estimator_
print(best_ngboost_model)
# Out:
# {'subsample': 0.8, 'reg_lambda': 0.5, 'reg_alpha': 0.5, 'num_leaves': 50, 'n_estimators': 500, 'min_samples_split': 5, 'min_samples_leaf': 6, 'min_child_weight': 1, 'max_depth': 20, 'learning_rate': 0.2, 'colsample_bytree': 1.0}
#
#
#
# NGBRegressor(learning_rate=0.2,
#              random_state=RandomState(MT19937) at 0x78853B233940)

# %%
test_set = pd.read_csv('test.csv')
Ids = test_set.iloc[:,0].values

# %%
test_set.drop(['id'],axis=1,inplace=True)
test_set.drop(['holiday'],axis=1,inplace=True)
test_set['date_time'] = pd.to_datetime(test_set['date_time'], format='%d-%m-%Y %H:%M')
test_set = create_date_features(test_set)

category_mapping={
  'Clear':1,'Clouds':2,'Mist':3,'Haze':4,'Smoke':5,'Drizzle':6,'Rain':7,'Thunderstorm':8,'Snow':9,'Squall':10,'Fog':11
}
test_set['weather_main'] = test_set['weather_main'].replace(category_mapping)
# test_set.head()

test_set.drop(['weather_description'],axis=1,inplace=True)
test_set.head(10)

# test_set.head()
# Out:
#          temp   rain_1h   snow_1h  clouds_all  weather_main  year  month  day  \
# 0  308.529564  2.022128  9.787501          40             9  2016     12    8
# 1  308.900616  2.022128  9.787501          40             9  2016     12    8
# 2  310.199297  3.033192  9.787501          75             9  2016     12    8
# 3  311.161712  5.055320  8.700001          90             9  2016     12    8
# 4  311.509574  1.011064  5.437500          90             9  2016     12    8
# 5  311.845839  3.033192  3.262500          90             9  2016     12    8
# 6  311.776267  9.099576  6.525001          90             9  2016     12    8
# 7  311.324048  0.000000  5.437500          90             9  2016     12    8
# 8  310.779065  1.011064  5.437500          90             9  2016     12    8
# 9  310.350037  7.077448  3.262500          90             9  2016     12    8
#
#    hour  dayofweek
# 0     8          3
# 1     9          3
# 2    10          3
# 3    11          3
# ...

# %%
best_y_pred = best_ngboost_model.predict(test_set)

# %%
# best_y_pred = best_estimator.predict(test_set)
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=7. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] Unknown parameter: min_samples_split

# %%
import pandas as pd
submission = pd.DataFrame({
    'ID': Ids,
    'traffic_volume': best_y_pred
})


file_path = '/content/submission.csv'

submission.to_csv(file_path, index=False)

from google.colab import files
files.download('/content/submission.csv')
